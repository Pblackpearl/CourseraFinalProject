# %% [markdown]
# Capstone Project Continued 2.2

# %%
#Installs
import requests
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json

from geopy.geocoders import Nominatim


#Matplotlib for plotting
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt

#Import K-Means for clustering
from sklearn.cluster import KMeans

# !conda install -c conda-forge folim=0.5.0 --yes
import folium

# !conda install -c anaconda xlrd --yes
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - folim=0.5.0
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge/linux-64
#   - https://conda.anaconda.org/conda-forge/noarch
#   - https://repo.anaconda.com/pkgs/main/linux-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/linux-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - xlrd
#
#
# ...

# %%
df_zipcodes=pd.read_excel('COVID19CONFIRMED_BYZIP_excel.xls')
print('data downloaded and read into a dataframe')
# Out:
# data downloaded and read into a dataframe

# %%
df_zipcodes.head()
# Out:
#    POSTCODE ConfirmedCaseCategory ConfirmedCaseCount
# 0     85347                     0                  0
# 1     85356                   1-5                1-5
# 2     85365                  6-10               6-10
# 3     85350                  6-10               6-10
# 4     85367                   1-5                1-5

# %%
print(df_zipcodes.shape)
# Out:
# (385, 3)

# %%
df_zipcodes.drop(['ConfirmedCaseCategory'], axis=1, inplace=True)

# %%
df_zipcodes.head(10)
# Out:
#    POSTCODE ConfirmedCaseCount
# 0     85347                  0
# 1     85356                1-5
# 2     85365               6-10
# 3     85350               6-10
# 4     85367                1-5
# 5     85364                 22
# 6     85349                 12
# 7     85352                  0
# 8     85336                  0
# 9     85344    Data Suppressed

# %%
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.style.use('ggplot')

# %%
df_zipcodes.plot(kind='hist', figsize=(40,20))

plt.xlabel('Post Code')
plt.ylabel('Case Confirmed')
plt.title('Arizona Coronavirus Cases by Zip Code')
          
plt.show()
